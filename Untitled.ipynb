# %%
# %%bash
# rostopic info tf
# Out:
# Type: tf2_msgs/TFMessage
#
# Publishers:
#  * /robot_state_publisher (http://localhost:45463/)
#
# Subscribers:
#  * /baxter_sim_kinematics_left (http://localhost:42585/)
#  * /baxter_sim_kinematics_right (http://localhost:33871/)
#  * /baxter_emulator (http://localhost:36079/)

# %%
# %%bash
# rostopic echo /tf -n 1
# Out:
# transforms:
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 49
#         nsecs: 349000000
#       frame_id: "torso"
#     child_frame_id: "head"
#     transform:
#       translation:
#         x: 0.06
#         y: 0.0
#         z: 0.686
#       rotation:
#         x: 0.0
#         y: 0.0
#         z: -4.54480192363e-05
#         w: 0.999999998967
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 49
#         nsecs: 349000000
#       frame_id: "left_gripper_base"
#     child_frame_id: "l_gripper_l_finger"
#     transform:
#       translation:
#         x: 0.0
#         y: 0.0193330270544
#         z: 0.02
#       rotation:
#         x: 0.0
#         y: 0.0
#         z: 0.0
#         w: 1.0
#   -
#     header:
#       seq: 0
#       stamp:
#         secs: 49
#         nsecs: 349000000
#       frame_id: "left_gripper_base"
#     child_frame_id: "l_gripper_r_finger"
#     transform:
#       translation:
#         x: 0.0
#         y: 0.0015001289001
# ...

# %%
# %%bash
# rostopic echo /robot/joint_states -n 1
# Out:
# header:
#   seq: 9430
#   stamp:
#     secs: 192
#     nsecs: 189000000
#   frame_id: ''
# name: [head_pan, l_gripper_l_finger_joint, l_gripper_r_finger_joint, left_e0, left_e1, left_s0,
#   left_s1, left_w0, left_w1, left_w2, r_gripper_l_finger_joint, r_gripper_r_finger_joint,
#   right_e0, right_e1, right_s0, right_s1, right_w0, right_w1, right_w2]
# position: [-0.0003524698499042245, 0.020833065815400644, 2.0133545766120662e-08, -0.016634871237481974, 0.4944600858087407, 0.19210958244560583, 1.0470001083434868, -0.1834905800646931, 0.026794234841350573, -0.014136931061933034, 0.020833049314365765, 5.963063687966585e-08, 0.013237039639291126, 0.5023680528681469, -0.27537157122028866, 1.0470026956009377, -0.810998867819908, -0.07703634259043657, -0.015618897393161468]
# ...

# %%
# %%bash
# chmod +x ~/robot_ws/src/bax/src/tf_listener.py
# Out:
# chmod: cannot access '/home/rflab/robot_ws/src/bax/src/tf_listener.py': No such file or directory

# %%
# %%bash
# chmod +x ~/ros_ws/src/bax/src/tf_listener.py

# %%
# %%bash
# chmod +x ~/ros_ws/src/bax/src/tf_listener.py
# Out:
# chmod: cannot access '/home/rflab/ros_ws/src/bax/src/tf_listener.py': No such file or directory

# %%
# %%bash
# chmod +x ~/ros_ws/src/mybaxter/src/tf_listener.py

# %%
# %%bash
# chmod +x ~/ros_ws/src/mybaxter/src/tf_listener.py

# %%
# %%bash
# cd ~/ros_ws/src/baxter/baxter_common/baxter_description/urdf
# cat baxter.urdf.xacro | grep "robot name"
# Out:
# <robot name="baxter" xmlns:xacro="http://www.ros.org/wiki/xacro">

# %%
# %%bash
# cd ~/ros_ws/src/baxter/baxter_common/baxter_description/urdf
# cat baxter.urdf.xacro | grep "default"
# Out:
#   <xacro:arg name="gazebo" default="false"/>
#   <xacro:arg name="pedestal" default="true"/>

# %%
# %%bash
# cd ~/ros_ws/src/baxter/baxter_common/baxter_description/urdf
# cat left_end_effector.urdf.xacro
# Out:
# <?xml version="1.0" ?>
# <robot name="left_end_effector" xmlns:xacro="http://www.ros.org/wiki/xacro">
#   <xacro:include filename="$(find rethink_ee_description)/urdf/electric_gripper/rethink_electric_gripper.xacro" />
#   <xacro:rethink_electric_gripper side="left"
#                                   l_finger="extended_narrow"
#                                   l_finger_slot="2"
#                                   l_finger_tip="paddle_tip"
#                                   l_finger_grasp="inner"
#                                   r_finger="extended_narrow"
#                                   r_finger_slot="2"
#                                   r_finger_tip="paddle_tip"
#                                   r_finger_grasp="inner"/>
# </robot>

# %%
# %%bash
# cd ~/ros_ws/src/baxter/baxter_common/rethink_ee_description/urdf/electric_gripper/
# cat rethink_electric_gripper.xacro
# Out:
# <?xml version="1.0"?>
# <robot xmlns:xacro="http://www.ros.org/wiki/xacro" name="rethink_electric_gripper">
#   <xacro:macro name="rethink_electric_gripper" params="side r_finger r_finger_slot r_finger_tip r_finger_grasp l_finger l_finger_slot l_finger_tip l_finger_grasp">
#     <xacro:property name="gripper_side" value="${side[0]}" scope="local"/>
#     <!-- Base of end effector -->
#     <link name="${side}_gripper_base">
#       <visual>
#         <origin rpy="${-pi/2} ${pi} 0" xyz="0 0 0"/>
#         <geometry>
#           <mesh filename="package://rethink_ee_description/meshes/electric_gripper/electric_gripper_base.DAE"/>
#         </geometry>
#       </visual>
#       <collision>
#         <origin rpy="${-pi/2} ${pi} 0" xyz="0.0 0.0 0"/>
#         <geometry>
#           <cylinder length="0.1" radius="0.029"/>
#         </geometry>
#         <material name="darkred">
#           <color rgba=".5 .1 .1 1"/>
#         </material>
#       </collision>
#       <inertial>
# ...

# %%
# %%bash
# chmod +x ~/ros_ws/src/mybaxter/src/move_baxter.py
